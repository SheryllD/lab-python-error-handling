# %%
# Step 1: Define the function for initializing the inventory with error handling

# This is the list of products
products = ["t-shirt", "mug", "hat", "book", "keychain"]

def initialize_inventory(products):
    inventory = {}
    for product in products:
        valid_quantity = False
        while not valid_quantity:
            try:
                quantity = int(input(f"Enter the quantity of {product}s available: "))
                if quantity <= 0:
                    raise ValueError("Invalid quantity! Please enter a non-negative value.")
                valid_quantity = True
            except ValueError as error:
                print(f"Error: {error}")
        inventory[product] = quantity
    return inventory

inventory = initialize_inventory(products)
print("We have the follow inventory in the shop: ", inventory)
# Out:
# We have the follow inventory in the shop:  {'t-shirt': 7, 'mug': 7, 'hat': 7, 'book': 7, 'keychain': 7}

# %%
# Or, in another way:

products = ["t-shirt", "mug", "hat", "book", "keychain"]

def initialize_inventory(products):
    inventory = {}
    for product in products:
        valid_input = False
        while not valid_input:
            try:
                quantity = int(input(f"Enter the quantity of {product}s available: "))
                if quantity >= 0:
                    inventory[product] = quantity
                    valid_input = True
                else:
                    print("Quantity cannot be negative. Please enter a valid quantity.")
            except ValueError:
                print("Invalid input. Please enter a valid quantity.")
    return inventory

inventory = initialize_inventory (products)
print("We have the follow inventory in the shop: ", inventory)
# Out:
# We have the follow inventory in the shop:  {'t-shirt': 7, 'mug': 7, 'hat': 7, 'book': 7, 'keychain': 7}

# %%
# Modify the calculate_total_price function to include error handling.
# Modify the get_customer_orders function to include error handling.

# This is my list of products. 
products = ["t-shirt", "mug", "hat", "book", "keychain"]
customer_orders = {}

# Here I am already defining the prices per product.
product_prices = {
    "t-shirt": 15.99, 
    "mug": 16.99, 
    "hat": 10.00, 
    "book": 29.00, 
    "keychain": 4.99
}

# This is a function to initialize the inventory. 
initialize_inventory = lambda products: {product: int(input(f"Please enter the amount for {product}: ")) for product in products}

# Here I am creating the inventory of my shop
inventory = initialize_inventory(products)
print("We have the follow inventory in the shop: ", inventory)

# Function to calculate the total price with error handeling
def calculate_total_price (customer_orders, product_prices): 
    total_cost = 0
    try: 
        for product, quantity in customer_orders.items():
            if product in product_prices:
                total_cost += quantity * product_prices[product]
            else: 
                print(f"Warning: no price available for {product}.")
    except ValueError: 
        print("Incorrect input")
    
    return total_cost

# Function to get customer orders with error handling. 
def get_customer_orders(inventory):
    valid_input = False
    while not valid_input:
        try: 
             customer_product_order_quantity = int(input("Enter the number of customer orders: "))
             if  customer_product_order_quantity >= 0: 
                 valid_input = True
             else:
                print("Invalid input. Please enter a valid number. ")
        except ValueError: 
            print("Invalid input. Please enter a valid number. ")

    customer_orders = set()    
    for _ in range (customer_product_order_quantity): 
        valid_product = False 
        while not valid_product:
            product_name = input("Enter the name of a product that a custumor wants to order: ")
            try: 
                if product_name in inventory and inventory[product_name] >0: 
                    customer_orders.add(product_name)
                    valid_product = True
                else: 
                    if product_name not in inventory: 
                        raise ValueError (f"Error: the {product_name} is not available in the inventory.")
                    else: 
                        raise ValueError (f"Error: {product_name} is out of stock! ")
            except ValueError as e: 
                print("str(e)")

    return customer_orders

 #   while True: 
 #       print(f"What products would you like to order? We have the following: {', '.join(inventory.keys())}")
 #       customer_order_list = [product.lower() for product in input("Enter the product names seperated by spaces: ").split()]#

#        for product in customer_order_list: 
#            if product not in inventory:
#                print(f"We don't have this {product} in our inventory.")
#                continue

#            while True: 
#                try: 
#                    customer_product_order_quantity = int(input(f"How many of {product} do you want to buy? "))
#                    if customer_product_order_quantity <= 0: 
#                        print("Please enter a quantity greater than zero.")
#                        continue
#                    elif customer_product_order_quantity > inventory[product]: 
#                        print(f"Sorry, we only have {inventory[product]} of {product}. Try again.")
#                        continue
#                    else: 
#                        customer_orders[product] = customer_product_order_quantity 
#                        print(f"Added {customer_product_order_quantity} x {product} to your order.")
#                        break
#                except ValueError: 
#                    print("Invalid input! Please enter a valid number.")

#        choice = input("Do you want to order more? (Yes/No): ").lower() 
#        if choice == "no": 
#             break 
        
#    return customer_orders #, calculate_total_price(customer_orders, product_prices)

#print(f"Total cost of your order: ${total_cost:.2f}")

# Function to update inventory after purchase with error handling
def update_inventory(inventory, customer_orders): 
    inventory = {product: inventory[product] -1 if product in customer_orders else inventory[product] for product in inventory}
    inventory = {product: quantity for product, quantity in inventory.items() if quantity >0}
    return inventory

# Define the function to calculate order statistics
def calculate_order_statistics(customers_orders, products): 
    total_products_ordered = len(customers_orders)
    percentage_ordered = (total_products_ordered / len(products)) *100 
    return total_products_ordered, percentage_ordered

# Define a function for printing order statistics 
def print_order_statistics(order_statistics): 
    print("Order Statistics: ")
    print("Total Products Ordered: ", order_statistics[0])
    print("Percentage of Unique Products Ordered: ", order_statistics[1])

# Define the function for printing the updated inventory
def print_updated_inventory(inventory): 
    print("Updated Inventory: ")
    [print(f"{product}: {quantity}") for product, quantity in inventory.items()]

# Define the function for calulating the total price of the customer order
def calculate_total_price(customer_orders): 
    total_price = 0 
    for product in customer_orders: 
        valid_input = False
        while not valid_input:
            try: 
                price = float(input(f"Enter the price of {product}: "))
                if price >= 0: 
                    total_price += price 
                    valid_input = True 
                else:
                    print("Price can't be negative. Please enter a valid price.")
            except ValueError: 
                print("Invalid input. Please enter a valid npeice")
    return total_price

# Call the functions in the appropriate sequence to manage customer orders

products = ["t-shirt", "mug", "hat", "book", "keychain"]
inventory = initialize_inventory(products)
customer_orders = get_customer_orders(inventory)
inventory = update_inventory(customer_orders, inventory)
order_statistics = calculate_order_statistics(customer_orders, products)
print_order_statistics(order_statistics)
print_updated_inventory(inventory)
total_price = calculate_total_price(customer_orders)
print("Total Price:", total_price)

# Updating the inventory after the purchase
update_inventory
# Out:
# We have the follow inventory in the shop:  {'t-shirt': 7, 'mug': 7, 'hat': 7, 'book': 7, 'keychain': 7}
# str(e)
# str(e)
# str(e)
